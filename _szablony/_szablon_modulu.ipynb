# %% [markdown]
# # Moduł {XX}: {Temat}
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JoziMate/python-course-notebooks-pl/blob/main/moduly/{XX}_{folder}/{XX}_{plik}.ipynb)
#
# W tym module nauczysz się:
# - {cel nauki 1},
# - {cel nauki 2},
# - {cel nauki 3}.
#
# Każde zadanie sprawdzisz funkcją `.sprawdz()`. Jeśli się zablokujesz — `.podpowiedz()` i `.rozwiazanie()` Ci pomogą.

# %% [markdown]
# ## Konfiguracja
# Uruchom poniższą komórkę — ściągnie ona framework do sprawdzania zadań i ich treść.

# %%
# !wget -q https://raw.githubusercontent.com/JoziMate/python-course-notebooks-pl/main/checker.py
# !wget -q https://raw.githubusercontent.com/JoziMate/python-course-notebooks-pl/main/cwiczenia/cwiczenie{XX}_{temat}.py
from cwiczenie{XX}_{temat} import zestaw
zestaw.wczytaj()

# %% [markdown]
# ## 1. {Tytuł sekcji teorii}
#
# {Opis konceptu — 2–4 zdania. Wyjaśnij ideę, pokaż składnię w bloku kodu jeśli trzeba.}
#
# ```python
# # {Przykład składni}
# {przyklad_kodu}
# ```

# %%
# Przykład — {opis przykładu}
{zmienna1} = {wartosc1}
{zmienna2} = {wartosc2}

print({zmienna1}, {zmienna2})
print(type({zmienna1}), type({zmienna2}))

# %% [markdown]
# ## 2. Twoja kolej — Zadanie 1
#
# **{Treść zadania 1 — co dokładnie ma zrobić uczeń.}**
#
# Napisz kod w komórce poniżej, uruchom ją, a potem uruchom komórkę z `z1.sprawdz()`.

# %%
# Miejsce na Twój kod
{nazwa_zmiennej_z1} = ...

# %%
z1.sprawdz()

# %% [markdown]
# Zablokowany? Odkomentuj i uruchom jedną z poniższych linii:

# %%
# z1.podpowiedz()
# z1.rozwiazanie()

# %% [markdown]
# ## 3. {Tytuł drugiej sekcji teorii}
#
# {Opis kolejnego konceptu powiązanego z modułem.}

# %%
# {Opis przykładu 2}
print({przyklad_wyrazenia})

# %% [markdown]
# ## 4. Twoja kolej — Zadanie 2
#
# **{Treść zadania 2.}**

# %%
# Miejsce na Twój kod
{nazwa_zmiennej_z2} = ...

# %%
z2.sprawdz()

# %%
# z2.podpowiedz()
# z2.rozwiazanie()

# %% [markdown]
# ## 5. Podsumowanie modułu

# %%
zestaw.postep()

# %% [markdown]
# ## Co dalej?
#
# W module {XX+1} zajmiemy się **{temat kolejnego modułu}** — {krótki opis co uczeń zyska}.
#
# Do zobaczenia na kanale! 🐍
