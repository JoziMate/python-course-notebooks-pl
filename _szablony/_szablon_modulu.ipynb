# %% [markdown]
# # Moduł {NUMER}: {TYTUŁ MODUŁU}
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JoziMate/python-course-notebooks-pl/blob/main/moduly/{FOLDER_MODULU}/{NAZWA_NOTEBOOKA}.ipynb)
# W tym module nauczysz się:
# - {punkt 1}
# - {punkt 2}
# - {punkt 3}

# %% [markdown]
# ## Konfiguracja
# Uruchom poniższą komórkę — ściągnie ona framework do sprawdzania zadań i ich treść.

# %%
# !wget -q https://raw.githubusercontent.com/JoziMate/python-course-notebooks-pl/main/checker.py
# !wget -q https://raw.githubusercontent.com/JoziMate/python-course-notebooks-pl/main/cwiczenia/cwiczenie{XX}_{temat}.py
from cwiczenie{XX}_{temat} import zestaw
zestaw.wczytaj()

# %% [markdown]
# ## 1. {Nazwa sekcji teoretycznej}
# {Wyjaśnienie pojęcia, najlepiej krótko i konkretnie — 3-5 akapitów max.}

# %%
# Przykład demonstracyjny (nie jest zadaniem, uczeń tylko czyta i uruchamia)

# %% [markdown]
# ## 2. Twoja kolej — Zadanie 1
# **{Treść zadania — co konkretnie uczeń ma zrobić}.**

# %%
# Miejsce na Twój kod

# %%
z1.sprawdz()

# %%
# z1.podpowiedz()
# z1.rozwiazanie()

# %% [markdown]
# ---
# > 💡 **Wzorzec do powielenia:** dla każdego kolejnego zadania w tym module skopiuj blok:
# > 1 komórka markdown z treścią zadania → 1 komórka kodu na rozwiązanie ucznia → 1 komórka z `zN.sprawdz()` → 1 komórka z zakomentowanymi `.podpowiedz()`/`.rozwiazanie()`.
# > Pamiętaj o dopisaniu odpowiadającego `zN` (Zadanie) w pliku `cwiczenie{XX}_{temat}.py`.
# ---

# %% [markdown]
# ## 3. {Kolejna sekcja teoretyczna, jeśli potrzebna}

# %%
# Kolejny przykład demonstracyjny

# %% [markdown]
# ## 4. Twoja kolej — Zadanie 2
# **{Treść zadania 2}.**

# %%
# Miejsce na Twój kod

# %%
z2.sprawdz()

# %%
# z2.podpowiedz()
# z2.rozwiazanie()

# %% [markdown]
# ## Podsumowanie modułu

# %%
zestaw.postep()

# %% [markdown]
# ## Co dalej?
# W module {NUMER+1} zajmiemy się **{temat następnego modułu}**.
# Do zobaczenia na kanale! 🐍
