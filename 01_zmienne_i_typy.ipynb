# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JoziMate/TWOJE-REPO/blob/main/moduly/01_podstawy/01_zmienne_i_typy.ipynb)
#
# # Moduł 1: Zmienne i typy danych
#
# W tym notebooku nauczysz się, jak deklarować zmienne w Pythonie i jakie podstawowe typy danych istnieją (`int`, `float`, `str`, `bool`).
#
# Każde zadanie sprawdzisz funkcją `.check()` — jeśli się zablokujesz, użyj `.hint()`, a jeśli chcesz zobaczyć przykładowe rozwiązanie, użyj `.solution()`.

# %% [markdown]
# ### Konfiguracja (uruchom tę komórkę jako pierwszą)
#
# Pobiera plik `checker.py` z repozytorium, żeby mechanizm sprawdzania zadań zadziałał w tym notebooku.

# %%
# !wget -q https://raw.githubusercontent.com/JoziMate/TWOJE-REPO/main/checker.py
from checker import Question

# %% [markdown]
# ## Wprowadzenie
#
# W Pythonie zmienną tworzysz po prostu przypisując jej wartość znakiem `=`. Nie musisz deklarować typu — Python sam go rozpozna.
#
# ```python
# wiek = 25        # int
# pi = 3.14        # float
# imie = "Józef"   # str
# czy_aktywny = True  # bool
# ```
#
# Typ zmiennej możesz sprawdzić funkcją `type()`.

# %%
wiek = 25
print(type(wiek))

# %% [markdown]
# ---
# ## Zadanie 1
#
# Stwórz zmienną o nazwie `moj_wiek` i przypisz jej swój wiek (jako liczbę całkowitą, `int`).
#
# Następnie uruchom komórkę sprawdzającą poniżej.

# %%
# TODO: stwórz zmienną moj_wiek i przypisz jej swój wiek
moj_wiek = ____

# %%
q1 = Question(
    answer_check=lambda: isinstance(moj_wiek, int) and moj_wiek > 0,
    hint="Sprawdź, czy moj_wiek to liczba całkowita (bez kropki dziesiętnej) i większa od zera.",
    solution="moj_wiek = 30",
    title="Zadanie 1"
)
q1.check()

# %% [markdown]
# ---
# ## Zadanie 2
#
# Stwórz zmienną `pole_kwadratu`, która obliczy pole kwadratu o boku 7 (wzór: `bok ** 2`).

# %%
# TODO: oblicz pole kwadratu o boku 7
bok = 7
pole_kwadratu = ____

# %%
q2 = Question(
    answer_check=lambda: pole_kwadratu == 49,
    hint="Pole kwadratu to bok podniesiony do kwadratu: bok ** 2.",
    solution="pole_kwadratu = bok ** 2",
    title="Zadanie 2"
)
q2.check()

# %% [markdown]
# ---
# ## Podsumowanie
#
# Gratulacje! Nauczyłeś się:
# - jak deklarować zmienne w Pythonie,
# - jakie są podstawowe typy danych (`int`, `float`, `str`, `bool`),
# - jak sprawdzić typ zmiennej funkcją `type()`.
#
# Przejdź do następnego notebooka: **02_operatory_i_warunki.ipynb**
